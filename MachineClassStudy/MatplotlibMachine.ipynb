# %%
import matplotlib.pyplot as plt # matplotlib 모듈 호출
X = range(100) # 0~99
Y = range(100) # 0~99
plt.plot(X, Y) # 그래프를 만듦

# %%
X = range(100) #0~99
Y = range(100) #0~99
plt.plot(X, Y)
plt.show() # 그래프를 출력

# %%
import numpy as np #numpy 모듈 호출
X_1 = range(100)
Y_1 = [np.cos(value) for value in X] 
X_2 = range(100)
Y_2 = [np.sin(value) for value in X]
plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)
plt.show()

# %%
fig, ax = plt.subplots() # (1) figure와 axes 객체 할당
X_1 = range(100)
Y_1 = [np.cos(value) for value in X]
ax.plot(X_1, Y_1) # (2) plot 함수를 사용하여 그래프 생성
ax.set(title='cos graph',xlabel='X', ylabel='Y')
# (3)그래프 제목,X축 라벨,Y축 라벨 설정
plt.show() # (4) 그래프 출력

# %%
fig = plt.figure() # (1) figure 반환
fig.set_size_inches(10, 5) # (2) figure의 크기 지정
ax_1 = fig.add_subplot(1,2,1) # (3) 첫 번째 그래프 생성 (행,열,1)
ax_2 = fig.add_subplot(1,2,2) # (4) 두 번째 그래프 생성 (행,열,2)
ax_1.plot(X_1, Y_1, c="b") # (5) 첫 번째 그래프 설정
ax_2.plot(X_2, Y_2, c="#FFAAFF") # (6) (색은 16진수컬러로 바꾸기 가능)
plt.show() # (7) 그래프 출력

# %%
# (1) x 값과 y_n 값 생성
x = np.linspace(-1,1,100) #-1~1까지 100개 숫자로 분할

y_1 = np.sin(x) # sin함수
y_2 = np.cos(x) # cos함수
y_3 = np.tan(x) # tan함수
y_4 = np.exp(x) # 지수함수(exponential)

fig, ax = plt.subplots(2, 2) # (2)2행 2열 figure 객체를 생성

ax[0, 0].plot(x, y_1) # (3) 첫 번째 그래프 생성
ax[0, 1].plot(x, y_2) # (4) 두 번째 그래프 생성
ax[1, 0].plot(x, y_3) # (5) 세 번째 그래프 생성
ax[1, 1].plot(x, y_4) # (6) 네 번째 그래프 생성

plt.show()

# %%
X_1 = range(100)
Y_1 = [value for value in X]
X_2 = range(100)
Y_2 = [value + 100 for value in X]
plt.plot(X_1, Y_1, color="#000000") 
plt.plot(X_2, Y_2, c="c") # color = c 단축 가능
plt.show()

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")
plt.plot(X_2, Y_2, c="r", ls="dotted")
plt.show()

# %%
fig = plt.figure() 
fig.set_size_inches(10,10)

ax_1 = fig.add_subplot(1,2,1) 
ax_2 = fig.add_subplot(1,2,2)

ax_1.plot(X_1, Y_1, c="b") 
ax_1.set_title("Figure 1")

ax_2.plot(X_2, Y_2, c="g") 
ax_2.set_title("Figure 2")

plt.show()

# %%
plt.plot(X_1, Y_1, 
color="b", 
linestyle="dashed", 
label='line_1')

plt.plot(X_2, Y_2, 
color="r", 
linestyle="dotted", 
label='line_2')

plt.legend( # 범례 (legend 함수를 사용한다)
shadow=True, 
fancybox=True, 
loc="lower right") # 범례 위치

plt.title('y = ax+b')
plt.xlabel('x_line')
plt.ylabel('y_line')
plt.show()

# %%
data_1 = np.random.rand(512, 2) #512행 2열
data_2 = np.random.rand(512, 2)

plt.scatter(data_1[:,0],data_1[:,1], c="b", marker="x")
plt.scatter(data_2[:,0],data_2[:,1], c="r", marker="o")
# scatter = 산점도(데이터의 분포도)

plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N) # 색깔을 랜덤하게 부여
area = np.pi * (15 * np.random.rand(N))**2 #원 넓이
plt.scatter(x, y, s=area, c=colors, alpha=0.5)# 산점도 커스텀마이징
# s = 원의 넓이, c = 색깔, alpha = 투명도 
plt.show()

# %%
# (1) 데이터 생성
data = [[5., 25., 50., 20.], # 파이썬에서 기본적으로 제공하는 데이터
[4., 23., 51., 17],
[6., 22., 52., 19]]

# (2) X 좌표 시작점
X = np.arange(0,8,2) #0~7까지 2간격으로 배열 생성 [0,2,4,6]

# (3) 3개의 막대그래프 생성 X+막대크기
plt.bar(X + 0.00, data[0], color = 'b', width = 0.50)
plt.bar(X + 0.50, data[1], color = 'g', width = 0.50)
plt.bar(X + 1.0, data[2], color = 'r', width = 0.50)

# (4) X축에 표시될 이름과 위치 설정
plt.xticks(X+0.50, ("A","B","C","D")) # 0.5로 그래프 가운데 정렬

# (5) 막대그래프 출력
plt.show()

# %%
# 누적 막대그래프

data = np.array([[5., 25., 50., 20.], # 넘파이 array에서 제공
                [4., 23., 51., 17],
                [6., 22., 52., 19]])

print(data)
data.shape
# Out:
# [[ 5. 25. 50. 20.]
#  [ 4. 23. 51. 17.]
#  [ 6. 22. 52. 19.]]
# (3, 4)

# %%
color_list = ['b', 'g', 'r']
data_label = ["A","B","C"]
X = np.arange(data.shape[1])
# data.shape=>[3,4]
#np.arange(4) => [0,1,2,3]
for i in range(3):
    plt.bar(X, data[i],
        bottom = np.sum(data[:i], axis=0), # [:i]행, axis=0(열방향)
        color = color_list[i],
        label=data_label[i])

plt.legend()
plt.show()

# %%
# 히스토그램(데이터의 분포 표현)

N = 1000 # 히스토그램 총 개수

X = np.random.normal(size=N) #정규분포로 램덤한 숫자 추출
plt.hist(X,bins=100) # hist = 히스토그램 생성, bins = 막대 개수

plt.show()

# %%
data = np.random.randn(100,5)#100행 5열 난수
plt.boxplot(data)
plt.show()
