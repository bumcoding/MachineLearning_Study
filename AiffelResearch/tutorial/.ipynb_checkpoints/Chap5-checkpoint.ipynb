# %%
'''
### 리스트(list)와 넘파이 배열(ndarray) 비교하기

- 파이썬 리스트 자료형은 수학적 계산을 하기에 매우 불리한 자료형입니다.
- 리스트에 덧셈과 곱셈을 시도해보면 바로 알 수 있습니다!
- 직접 행렬의 덧셈과 스칼라곱을 리스트와 넘파이 배열로 구현해보고 확인해봅시다.

### 조건
    
두 행렬에 대해서 다음을 계산하는 코드를 리스트와 넘파이를 사용해서 각각 구현해 보세요. 
A = (1 2) B = (5 6)
     3 4       7 8
   
- 1. A+B
- 2. 2A
'''

# %%
# 리스트로 행렬 정의
A = [[1, 2], [3, 4]]
B = [[5, 6], [7, 8]]

# 1. A + B
add_result = [
    [A[i][j] + B[i][j] for j in range(len(A[0]))]
    for i in range(len(A))
]

# 2. 2A
scalar_result = [
    [2 * A[i][j] for j in range(len(A[0]))]
    for i in range(len(A))
]

print("리스트 덧셈 결과:", add_result)
print("리스트 스칼라곱 결과:", scalar_result)

# %%
import numpy as np

# 넘파이 배열로 행렬 정의
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# 1. A + B
add_result = A + B

# 2. 2A
scalar_result = 2 * A

print("넘파이 덧셈 결과:\n", add_result)
print("넘파이 스칼라곱 결과:\n", scalar_result)
